# %% [markdown]
# <a href="https://colab.research.google.com/github/yukiregista/DSC_STUDY/blob/sinsukehlab%2Fbaseline/FinDataChallenge/takaito/FDUA2_takaito_baseline_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
# ====================================================
# Library
# ====================================================
import os
import gc
import warnings
warnings.filterwarnings('ignore')
import random
import scipy as sp
import numpy as np
import pandas as pd
from glob import glob
from pathlib import Path
import joblib
import pickle
import itertools
from tqdm.auto import tqdm

import torch
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split, GroupKFold
from sklearn.metrics import log_loss, roc_auc_score, matthews_corrcoef, f1_score
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import xgboost as xgb
from catboost import Pool, CatBoostRegressor, CatBoostClassifier

# %%
# ====================================================
# Configurations
# ====================================================
class CFG:
    VER = 1
    AUTHOR = 'takaito'
    COMPETITION = 'FUDA2'
    DATA_PATH = Path('/content/drive/MyDrive/Colab Notebooks/FUDA2/data')
    OOF_DATA_PATH = Path('/content/drive/MyDrive/Colab Notebooks/FUDA2/oof')
    MODEL_DATA_PATH = Path('/content/drive/MyDrive/Colab Notebooks/FUDA2/models')
    SUB_DATA_PATH = Path('/content/drive/MyDrive/Colab Notebooks/FUDA2/submission')
    METHOD_LIST = ['lightgbm', 'xgboost', 'catboost']
    seed = 42
    n_folds = 7
    target_col = 'MIS_Status'
    metric = 'f1_score'
    metric_maximize_flag = True
    num_boost_round = 500
    early_stopping_round = 200
    verbose = 25
    classification_lgb_params = {
        'objective': 'binary',
        'metric': 'auc',
        'learning_rate': 0.05,
        'seed': seed,
    }
    classification_xgb_params = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'learning_rate': 0.05,
        'random_state': seed,
    }

    classification_cat_params = {
        'learning_rate': 0.05,
        'iterations': num_boost_round,
        'random_seed': seed,
    }
    model_weight_dict = {'lightgbm': 0.50, 'xgboost': 0.10, 'catboost': 0.40}

# %%
# ====================================================
# Seed everything
# ====================================================
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

seed_everything(CFG.seed)

# %%
# ====================================================
# Metric
# ====================================================
# f1_score

# ====================================================
# LightGBM Metric
# ====================================================
def lgb_metric(y_pred, y_true):
    y_true = y_true.get_label()
    return 'f1score', f1_score(y_true, np.where(y_pred >= 0.5, 1, 0), average='macro'), CFG.metric_maximize_flag

# ====================================================
# XGBoost Metric
# ====================================================
def xgb_metric(y_pred, y_true):
    y_true = y_true.get_label()
    return 'f1score', f1_score(y_true, np.where(y_pred >= 0.5, 1, 0), average='macro')

# %%
train_df = pd.read_csv(CFG.DATA_PATH / 'train.csv', index_col=0)
test_df = pd.read_csv(CFG.DATA_PATH / 'test.csv', index_col=0)

# %%
default_numerical_features = ['Term', 'NoEmp', 'CreateJob', 'RetainedJob', 'DisbursementGross', 'GrAppv', 'SBA_Appv', 'ApprovalFY']
default_categorical_features = ['NewExist', 'FranchiseCode', 'RevLineCr', 'LowDoc', 'UrbanRural', 'State', 'BankState', 'City', 'Sector']
add_numerical_features = ['FranchiseCode_count_encoding', 'RevLineCr_count_encoding', 'LowDoc_count_encoding', 'UrbanRural_count_encoding', 'State_count_encoding', 'BankState_count_encoding', 'City_count_encoding', 'Sector_count_encoding']
numerical_features = add_numerical_features + default_numerical_features
categorical_features = ['RevLineCr', 'LowDoc', 'UrbanRural', 'State', 'Sector']
features = numerical_features + categorical_features

# %%
def Preprocessing(input_df: pd.DataFrame()) -> pd.DataFrame():
    def deal_missing(input_df: pd.DataFrame()) -> pd.DataFrame():
        output_df = input_df.copy()
        for col in ['RevLineCr', 'LowDoc', 'BankState', 'DisbursementDate']:
            output_df[col] = input_df[col].fillna('[UNK]')
        return output_df
    def clean_money(input_df: pd.DataFrame()) -> pd.DataFrame():
        output_df = input_df.copy()
        for col in ['DisbursementGross', 'GrAppv', 'SBA_Appv']:
            output_df[col] = input_df[col].str[1:].str.replace(',', '').str.replace(' ', '').astype(float)
        return output_df
    output_df = deal_missing(input_df)
    output_df = clean_money(output_df)
    output_df['NewExist'] = np.where(input_df['NewExist'] == 1, 1, 0)
    def make_features(input_df: pd.DataFrame()) -> pd.DataFrame():
        output_df = input_df.copy()
        # いろいろ特徴量作成を追加する
        return output_df
    output_df = make_features(output_df)
    return output_df

# %%
train_df = Preprocessing(train_df)
test_df = Preprocessing(test_df)

# %% [markdown]
# （以下はPreprocessingに本来組み込むべきだが，コードが煩雑になるので，いったん切り出している．）

# %%
for col in ['FranchiseCode', 'RevLineCr', 'LowDoc', 'UrbanRural', 'State', 'BankState', 'City', 'Sector']:
    count_dict = dict(train_df[col].value_counts())
    train_df[f'{col}_count_encoding'] = train_df[col].map(count_dict)
    test_df[f'{col}_count_encoding'] = test_df[col].map(count_dict).fillna(1).astype(int)

for col in categorical_features:
    encoder = LabelEncoder()
    encoder.fit(train_df[col])
    train_df[col] = encoder.transform(train_df[col])
    test_df[col] = encoder.transform(test_df[col])

# %%
def lightgbm_training(x_train: pd.DataFrame, y_train: pd.DataFrame, x_valid: pd.DataFrame, y_valid: pd.DataFrame, features: list, categorical_features: list):
    lgb_train = lgb.Dataset(x_train, y_train, categorical_feature=categorical_features)
    lgb_valid = lgb.Dataset(x_valid, y_valid, categorical_feature=categorical_features)
    model = lgb.train(
                params = CFG.classification_lgb_params,
                train_set = lgb_train,
                num_boost_round = CFG.num_boost_round,
                valid_sets = [lgb_train, lgb_valid],
                feval = lgb_metric,
                callbacks=[lgb.early_stopping(stopping_rounds=CFG.early_stopping_round,
                                              verbose=CFG.verbose)]
            )
    # Predict validation
    valid_pred = model.predict(x_valid)
    return model, valid_pred
def xgboost_training(x_train: pd.DataFrame, y_train: pd.DataFrame, x_valid: pd.DataFrame, y_valid: pd.DataFrame, features: list, categorical_features: list):
    xgb_train = xgb.DMatrix(data=x_train, label=y_train)
    xgb_valid = xgb.DMatrix(data=x_valid, label=y_valid)
    model = xgb.train(
                CFG.classification_xgb_params,
                dtrain = xgb_train,
                num_boost_round = CFG.num_boost_round,
                evals = [(xgb_train, 'train'), (xgb_valid, 'eval')],
                early_stopping_rounds = CFG.early_stopping_round,
                verbose_eval = CFG.verbose,
                feval = xgb_metric,
                maximize = CFG.metric_maximize_flag,
            )
    # Predict validation
    valid_pred = model.predict(xgb.DMatrix(x_valid))
    return model, valid_pred
def catboost_training(x_train: pd.DataFrame, y_train: pd.DataFrame, x_valid: pd.DataFrame, y_valid: pd.DataFrame, features: list, categorical_features: list):
    cat_train = Pool(data=x_train, label=y_train, cat_features=categorical_features)
    cat_valid = Pool(data=x_valid, label=y_valid, cat_features=categorical_features)
    model = CatBoostClassifier(**CFG.classification_cat_params)
    model.fit(cat_train,
              eval_set = [cat_valid],
              early_stopping_rounds = CFG.early_stopping_round,
              verbose = CFG.verbose,
              use_best_model = True)
    # Predict validation
    valid_pred = model.predict_proba(x_valid)[:, 1]
    return model, valid_pred

def gradient_boosting_model_cv_training(method: str, train_df: pd.DataFrame, features: list, categorical_features: list):
    # Create a numpy array to store out of folds predictions
    oof_predictions = np.zeros(len(train_df))
    oof_fold = np.zeros(len(train_df))
    kfold = KFold(n_splits=CFG.n_folds, shuffle=True, random_state=CFG.seed)
    for fold, (train_index, valid_index) in enumerate(kfold.split(train_df)):
        print('-'*50)
        print(f'{method} training fold {fold+1}')

        x_train = train_df[features].iloc[train_index]
        y_train = train_df[CFG.target_col].iloc[train_index]
        x_valid = train_df[features].iloc[valid_index]
        y_valid = train_df[CFG.target_col].iloc[valid_index]
        if method == 'lightgbm':
            model, valid_pred = lightgbm_training(x_train, y_train, x_valid, y_valid, features, categorical_features)
        if method == 'xgboost':
            model, valid_pred = xgboost_training(x_train, y_train, x_valid, y_valid, features, categorical_features)
        if method == 'catboost':
            model, valid_pred = catboost_training(x_train, y_train, x_valid, y_valid, features, categorical_features)

        # Save best model
        pickle.dump(model, open(CFG.MODEL_DATA_PATH / f'{method}_fold{fold + 1}_seed{CFG.seed}_ver{CFG.VER}.pkl', 'wb'))
        # Add to out of folds array
        oof_predictions[valid_index] = valid_pred
        oof_fold[valid_index] = fold + 1
        del x_train, x_valid, y_train, y_valid, model, valid_pred
        gc.collect()

    # Compute out of folds metric
    score = f1_score(train_df[CFG.target_col], oof_predictions >= 0.5, average='macro')
    print(f'{method} our out of folds CV f1score is {score}')
    # Create a dataframe to store out of folds predictions
    oof_df = pd.DataFrame({CFG.target_col: train_df[CFG.target_col], f'{method}_prediction': oof_predictions, 'fold': oof_fold})
    oof_df.to_csv(CFG.OOF_DATA_PATH / f'oof_{method}_seed{CFG.seed}_ver{CFG.VER}.csv', index = False)

def Learning(input_df: pd.DataFrame, features: list, categorical_features: list):
    for method in CFG.METHOD_LIST:
        gradient_boosting_model_cv_training(method, input_df, features, categorical_features)

# %%
Learning(train_df, features, categorical_features)
# Out:
# --------------------------------------------------
# lightgbm training fold 1
# [LightGBM] [Info] Number of positive: 32336, number of negative: 3927
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007063 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1726
# [LightGBM] [Info] Number of data points in the train set: 36263, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.891708 -> initscore=2.108305
# [LightGBM] [Info] Start training from score 2.108305
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [162]	training's auc: 0.893502	training's f1score: 0.677756	valid_1's auc: 0.758296	valid_1's f1score: 0.628923
# --------------------------------------------------
# lightgbm training fold 2
# [LightGBM] [Info] Number of positive: 32389, number of negative: 3874
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007829 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1718
# [LightGBM] [Info] Number of data points in the train set: 36263, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.893169 -> initscore=2.123531
# [LightGBM] [Info] Start training from score 2.123531
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [78]	training's auc: 0.849515	training's f1score: 0.656483	valid_1's auc: 0.779488	valid_1's f1score: 0.634775
# --------------------------------------------------
# lightgbm training fold 3
# [LightGBM] [Info] Number of positive: 32375, number of negative: 3888
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009932 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1728
# [LightGBM] [Info] Number of data points in the train set: 36263, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.892783 -> initscore=2.119492
# [LightGBM] [Info] Start training from score 2.119492
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [147]	training's auc: 0.888339	training's f1score: 0.670223	valid_1's auc: 0.775524	valid_1's f1score: 0.638506
# --------------------------------------------------
# lightgbm training fold 4
# [LightGBM] [Info] Number of positive: 32353, number of negative: 3910
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006836 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1722
# [LightGBM] [Info] Number of data points in the train set: 36263, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.892177 -> initscore=2.113169
# [LightGBM] [Info] Start training from score 2.113169
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [76]	training's auc: 0.84838	training's f1score: 0.656485	valid_1's auc: 0.779594	valid_1's f1score: 0.654788
# --------------------------------------------------
# lightgbm training fold 5
# [LightGBM] [Info] Number of positive: 32363, number of negative: 3900
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004604 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1721
# [LightGBM] [Info] Number of data points in the train set: 36263, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.892452 -> initscore=2.116039
# [LightGBM] [Info] Start training from score 2.116039
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [133]	training's auc: 0.877989	training's f1score: 0.670827	valid_1's auc: 0.780085	valid_1's f1score: 0.650226
# --------------------------------------------------
# lightgbm training fold 6
# [LightGBM] [Info] Number of positive: 32423, number of negative: 3840
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004914 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1721
# [LightGBM] [Info] Number of data points in the train set: 36263, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.894107 -> initscore=2.133396
# [LightGBM] [Info] Start training from score 2.133396
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [111]	training's auc: 0.86945	training's f1score: 0.663295	valid_1's auc: 0.779347	valid_1's f1score: 0.652549
# --------------------------------------------------
# lightgbm training fold 7
# [LightGBM] [Info] Number of positive: 32363, number of negative: 3901
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006979 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1719
# [LightGBM] [Info] Number of data points in the train set: 36264, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.892428 -> initscore=2.115783
# [LightGBM] [Info] Start training from score 2.115783
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [156]	training's auc: 0.892466	training's f1score: 0.673706	valid_1's auc: 0.774653	valid_1's f1score: 0.64414
# lightgbm our out of folds CV f1score is 0.6435944382182013
# --------------------------------------------------
# xgboost training fold 1
# [0]	train-logloss:0.35224	train-f1score:0.47138	eval-logloss:0.34264	eval-f1score:0.47329
# [25]	train-logloss:0.28694	train-f1score:0.65381	eval-logloss:0.28924	eval-f1score:0.61404
# [50]	train-logloss:0.26898	train-f1score:0.66654	eval-logloss:0.27952	eval-f1score:0.62849
# [75]	train-logloss:0.25932	train-f1score:0.67556	eval-logloss:0.27735	eval-f1score:0.63594
# [100]	train-logloss:0.25397	train-f1score:0.67985	eval-logloss:0.27683	eval-f1score:0.63784
# [125]	train-logloss:0.24953	train-f1score:0.68610	eval-logloss:0.27662	eval-f1score:0.63947
# [150]	train-logloss:0.24645	train-f1score:0.69024	eval-logloss:0.27686	eval-f1score:0.64024
# [175]	train-logloss:0.24337	train-f1score:0.69439	eval-logloss:0.27686	eval-f1score:0.64378
# [200]	train-logloss:0.23959	train-f1score:0.70052	eval-logloss:0.27678	eval-f1score:0.64477
# [225]	train-logloss:0.23675	train-f1score:0.70377	eval-logloss:0.27695	eval-f1score:0.64353
# [250]	train-logloss:0.23393	train-f1score:0.70734	eval-logloss:0.27697	eval-f1score:0.64626
# [275]	train-logloss:0.23022	train-f1score:0.71131	eval-logloss:0.27689	eval-f1score:0.65048
# [300]	train-logloss:0.22654	train-f1score:0.71686	eval-logloss:0.27722	eval-f1score:0.65048
# [325]	train-logloss:0.22333	train-f1score:0.72226	eval-logloss:0.27759	eval-f1score:0.64924
# [350]	train-logloss:0.22015	train-f1score:0.72655	eval-logloss:0.27800	eval-f1score:0.64998
# [375]	train-logloss:0.21728	train-f1score:0.73304	eval-logloss:0.27826	eval-f1score:0.65196
# [400]	train-logloss:0.21400	train-f1score:0.73737	eval-logloss:0.27890	eval-f1score:0.65171
# [425]	train-logloss:0.21077	train-f1score:0.74308	eval-logloss:0.27940	eval-f1score:0.65539
# [450]	train-logloss:0.20785	train-f1score:0.75035	eval-logloss:0.27984	eval-f1score:0.65416
# [475]	train-logloss:0.20475	train-f1score:0.75594	eval-logloss:0.28022	eval-f1score:0.65536
# [499]	train-logloss:0.20248	train-f1score:0.75946	eval-logloss:0.28062	eval-f1score:0.65608
# --------------------------------------------------
# xgboost training fold 2
# [0]	train-logloss:0.34984	train-f1score:0.47179	eval-logloss:0.35528	eval-f1score:0.47085
# [25]	train-logloss:0.28521	train-f1score:0.64884	eval-logloss:0.29642	eval-f1score:0.64043
# [50]	train-logloss:0.26810	train-f1score:0.65973	eval-logloss:0.28706	eval-f1score:0.65681
# [75]	train-logloss:0.25852	train-f1score:0.67300	eval-logloss:0.28434	eval-f1score:0.66010
# [100]	train-logloss:0.25215	train-f1score:0.68144	eval-logloss:0.28398	eval-f1score:0.66407
# [125]	train-logloss:0.24713	train-f1score:0.68577	eval-logloss:0.28414	eval-f1score:0.66563
# [150]	train-logloss:0.24373	train-f1score:0.69036	eval-logloss:0.28415	eval-f1score:0.66677
# [175]	train-logloss:0.23980	train-f1score:0.69532	eval-logloss:0.28466	eval-f1score:0.66831
# [200]	train-logloss:0.23540	train-f1score:0.70077	eval-logloss:0.28499	eval-f1score:0.66731
# [225]	train-logloss:0.23230	train-f1score:0.70573	eval-logloss:0.28538	eval-f1score:0.66706
# [250]	train-logloss:0.22934	train-f1score:0.70903	eval-logloss:0.28592	eval-f1score:0.66833
# [275]	train-logloss:0.22591	train-f1score:0.71427	eval-logloss:0.28648	eval-f1score:0.66645
# [300]	train-logloss:0.22262	train-f1score:0.72032	eval-logloss:0.28726	eval-f1score:0.66846
# [325]	train-logloss:0.21938	train-f1score:0.72564	eval-logloss:0.28809	eval-f1score:0.66428
# [350]	train-logloss:0.21615	train-f1score:0.73095	eval-logloss:0.28818	eval-f1score:0.66581
# [375]	train-logloss:0.21324	train-f1score:0.73625	eval-logloss:0.28867	eval-f1score:0.66542
# [400]	train-logloss:0.21063	train-f1score:0.74118	eval-logloss:0.28906	eval-f1score:0.66225
# [425]	train-logloss:0.20772	train-f1score:0.74577	eval-logloss:0.28940	eval-f1score:0.66428
# [450]	train-logloss:0.20506	train-f1score:0.75038	eval-logloss:0.28967	eval-f1score:0.66517
# [475]	train-logloss:0.20196	train-f1score:0.75469	eval-logloss:0.29018	eval-f1score:0.66354
# [499]	train-logloss:0.19959	train-f1score:0.75718	eval-logloss:0.29081	eval-f1score:0.66496
# --------------------------------------------------
# xgboost training fold 3
# [0]	train-logloss:0.35046	train-f1score:0.47168	eval-logloss:0.35179	eval-f1score:0.47149
# [25]	train-logloss:0.28532	train-f1score:0.65065	eval-logloss:0.29416	eval-f1score:0.63863
# [50]	train-logloss:0.26791	train-f1score:0.66233	eval-logloss:0.28414	eval-f1score:0.65018
# [75]	train-logloss:0.25863	train-f1score:0.67051	eval-logloss:0.28229	eval-f1score:0.66024
# [100]	train-logloss:0.25270	train-f1score:0.67941	eval-logloss:0.28191	eval-f1score:0.66094
# [125]	train-logloss:0.24821	train-f1score:0.68703	eval-logloss:0.28194	eval-f1score:0.65971
# [150]	train-logloss:0.24455	train-f1score:0.69041	eval-logloss:0.28208	eval-f1score:0.66078
# [175]	train-logloss:0.24158	train-f1score:0.69423	eval-logloss:0.28200	eval-f1score:0.66274
# [200]	train-logloss:0.23845	train-f1score:0.69805	eval-logloss:0.28208	eval-f1score:0.66185
# [225]	train-logloss:0.23448	train-f1score:0.70173	eval-logloss:0.28241	eval-f1score:0.66176
# [250]	train-logloss:0.23122	train-f1score:0.70687	eval-logloss:0.28256	eval-f1score:0.66265
# [275]	train-logloss:0.22801	train-f1score:0.71144	eval-logloss:0.28264	eval-f1score:0.66408
# [300]	train-logloss:0.22536	train-f1score:0.71527	eval-logloss:0.28278	eval-f1score:0.66295
# [325]	train-logloss:0.22171	train-f1score:0.71998	eval-logloss:0.28313	eval-f1score:0.66486
# [350]	train-logloss:0.21843	train-f1score:0.72649	eval-logloss:0.28335	eval-f1score:0.66310
# [375]	train-logloss:0.21472	train-f1score:0.73174	eval-logloss:0.28385	eval-f1score:0.66514
# [400]	train-logloss:0.21175	train-f1score:0.73791	eval-logloss:0.28420	eval-f1score:0.66086
# [425]	train-logloss:0.20878	train-f1score:0.74433	eval-logloss:0.28451	eval-f1score:0.66238
# [450]	train-logloss:0.20627	train-f1score:0.74985	eval-logloss:0.28502	eval-f1score:0.66150
# [475]	train-logloss:0.20386	train-f1score:0.75488	eval-logloss:0.28536	eval-f1score:0.66062
# [499]	train-logloss:0.20147	train-f1score:0.75952	eval-logloss:0.28582	eval-f1score:0.66252
# --------------------------------------------------
# xgboost training fold 4
# [0]	train-logloss:0.35169	train-f1score:0.47151	eval-logloss:0.34595	eval-f1score:0.47251
# [25]	train-logloss:0.28738	train-f1score:0.64895	eval-logloss:0.28439	eval-f1score:0.65404
# [50]	train-logloss:0.26963	train-f1score:0.65952	eval-logloss:0.27396	eval-f1score:0.66141
# [75]	train-logloss:0.25979	train-f1score:0.66988	eval-logloss:0.27158	eval-f1score:0.66638
# [100]	train-logloss:0.25415	train-f1score:0.67600	eval-logloss:0.27058	eval-f1score:0.66619
# [125]	train-logloss:0.24888	train-f1score:0.68390	eval-logloss:0.27025	eval-f1score:0.66987
# [150]	train-logloss:0.24458	train-f1score:0.68848	eval-logloss:0.27079	eval-f1score:0.66652
# [175]	train-logloss:0.24128	train-f1score:0.69360	eval-logloss:0.27093	eval-f1score:0.66908
# [200]	train-logloss:0.23841	train-f1score:0.69883	eval-logloss:0.27106	eval-f1score:0.67068
# [225]	train-logloss:0.23519	train-f1score:0.70411	eval-logloss:0.27112	eval-f1score:0.67109
# [250]	train-logloss:0.23199	train-f1score:0.70955	eval-logloss:0.27119	eval-f1score:0.67201
# [275]	train-logloss:0.22829	train-f1score:0.71594	eval-logloss:0.27110	eval-f1score:0.67175
# [300]	train-logloss:0.22445	train-f1score:0.72150	eval-logloss:0.27134	eval-f1score:0.67478
# [325]	train-logloss:0.22135	train-f1score:0.72670	eval-logloss:0.27203	eval-f1score:0.67543
# [350]	train-logloss:0.21781	train-f1score:0.73140	eval-logloss:0.27245	eval-f1score:0.67608
# [375]	train-logloss:0.21449	train-f1score:0.73663	eval-logloss:0.27295	eval-f1score:0.67215
# [400]	train-logloss:0.21212	train-f1score:0.74102	eval-logloss:0.27342	eval-f1score:0.67150
# [425]	train-logloss:0.20916	train-f1score:0.74725	eval-logloss:0.27408	eval-f1score:0.67006
# [450]	train-logloss:0.20617	train-f1score:0.75133	eval-logloss:0.27485	eval-f1score:0.67020
# [475]	train-logloss:0.20353	train-f1score:0.75514	eval-logloss:0.27552	eval-f1score:0.66929
# [499]	train-logloss:0.20044	train-f1score:0.76084	eval-logloss:0.27611	eval-f1score:0.66903
# --------------------------------------------------
# xgboost training fold 5
# [0]	train-logloss:0.35113	train-f1score:0.47158	eval-logloss:0.34877	eval-f1score:0.47205
# [25]	train-logloss:0.28722	train-f1score:0.65209	eval-logloss:0.28973	eval-f1score:0.63576
# [50]	train-logloss:0.26984	train-f1score:0.66341	eval-logloss:0.27815	eval-f1score:0.64746
# [75]	train-logloss:0.26005	train-f1score:0.67168	eval-logloss:0.27494	eval-f1score:0.65394
# [100]	train-logloss:0.25275	train-f1score:0.67942	eval-logloss:0.27328	eval-f1score:0.66186
# [125]	train-logloss:0.24813	train-f1score:0.68430	eval-logloss:0.27274	eval-f1score:0.66799
# [150]	train-logloss:0.24481	train-f1score:0.68966	eval-logloss:0.27251	eval-f1score:0.66866
# [175]	train-logloss:0.24195	train-f1score:0.69331	eval-logloss:0.27253	eval-f1score:0.66866
# [200]	train-logloss:0.23874	train-f1score:0.69707	eval-logloss:0.27267	eval-f1score:0.66908
# [225]	train-logloss:0.23568	train-f1score:0.70108	eval-logloss:0.27281	eval-f1score:0.67095
# [250]	train-logloss:0.23243	train-f1score:0.70684	eval-logloss:0.27330	eval-f1score:0.67307
# [275]	train-logloss:0.22911	train-f1score:0.71094	eval-logloss:0.27375	eval-f1score:0.67254
# [300]	train-logloss:0.22613	train-f1score:0.71598	eval-logloss:0.27415	eval-f1score:0.67122
# [325]	train-logloss:0.22232	train-f1score:0.72236	eval-logloss:0.27442	eval-f1score:0.67149
# [350]	train-logloss:0.21837	train-f1score:0.72751	eval-logloss:0.27480	eval-f1score:0.66938
# [375]	train-logloss:0.21580	train-f1score:0.73219	eval-logloss:0.27486	eval-f1score:0.66819
# [400]	train-logloss:0.21293	train-f1score:0.73729	eval-logloss:0.27512	eval-f1score:0.67175
# [425]	train-logloss:0.21070	train-f1score:0.74134	eval-logloss:0.27526	eval-f1score:0.67280
# [435]	train-logloss:0.20990	train-f1score:0.74223	eval-logloss:0.27537	eval-f1score:0.67018
# --------------------------------------------------
# xgboost training fold 6
# [0]	train-logloss:0.34823	train-f1score:0.47205	eval-logloss:0.36352	eval-f1score:0.46927
# [25]	train-logloss:0.28532	train-f1score:0.64744	eval-logloss:0.30175	eval-f1score:0.64703
# [50]	train-logloss:0.26794	train-f1score:0.66055	eval-logloss:0.29041	eval-f1score:0.65869
# [75]	train-logloss:0.25787	train-f1score:0.66809	eval-logloss:0.28723	eval-f1score:0.66737
# [100]	train-logloss:0.25178	train-f1score:0.67440	eval-logloss:0.28634	eval-f1score:0.67369
# [125]	train-logloss:0.24715	train-f1score:0.67966	eval-logloss:0.28623	eval-f1score:0.67546
# [150]	train-logloss:0.24321	train-f1score:0.68477	eval-logloss:0.28629	eval-f1score:0.67481
# [175]	train-logloss:0.24003	train-f1score:0.68938	eval-logloss:0.28637	eval-f1score:0.67373
# [200]	train-logloss:0.23712	train-f1score:0.69405	eval-logloss:0.28652	eval-f1score:0.67358
# [225]	train-logloss:0.23373	train-f1score:0.69947	eval-logloss:0.28669	eval-f1score:0.67416
# [250]	train-logloss:0.23130	train-f1score:0.70393	eval-logloss:0.28679	eval-f1score:0.67367
# [275]	train-logloss:0.22805	train-f1score:0.70930	eval-logloss:0.28715	eval-f1score:0.67647
# [300]	train-logloss:0.22530	train-f1score:0.71240	eval-logloss:0.28773	eval-f1score:0.67818
# [325]	train-logloss:0.22233	train-f1score:0.71597	eval-logloss:0.28786	eval-f1score:0.67687
# [350]	train-logloss:0.21835	train-f1score:0.72147	eval-logloss:0.28853	eval-f1score:0.67638
# [375]	train-logloss:0.21512	train-f1score:0.72624	eval-logloss:0.28903	eval-f1score:0.67614
# [400]	train-logloss:0.21197	train-f1score:0.73140	eval-logloss:0.28950	eval-f1score:0.67581
# [425]	train-logloss:0.20883	train-f1score:0.73684	eval-logloss:0.29003	eval-f1score:0.67581
# [450]	train-logloss:0.20571	train-f1score:0.74201	eval-logloss:0.29057	eval-f1score:0.67638
# [475]	train-logloss:0.20243	train-f1score:0.74856	eval-logloss:0.29117	eval-f1score:0.67614
# [480]	train-logloss:0.20191	train-f1score:0.74962	eval-logloss:0.29136	eval-f1score:0.67751
# --------------------------------------------------
# xgboost training fold 7
# [0]	train-logloss:0.35104	train-f1score:0.47158	eval-logloss:0.34860	eval-f1score:0.47209
# [25]	train-logloss:0.28574	train-f1score:0.65297	eval-logloss:0.29292	eval-f1score:0.63346
# [50]	train-logloss:0.26830	train-f1score:0.66370	eval-logloss:0.28418	eval-f1score:0.64274
# [75]	train-logloss:0.25805	train-f1score:0.67302	eval-logloss:0.28143	eval-f1score:0.64610
# [100]	train-logloss:0.25191	train-f1score:0.68016	eval-logloss:0.28033	eval-f1score:0.64911
# [125]	train-logloss:0.24704	train-f1score:0.68578	eval-logloss:0.27987	eval-f1score:0.64909
# [150]	train-logloss:0.24316	train-f1score:0.69050	eval-logloss:0.27981	eval-f1score:0.65065
# [175]	train-logloss:0.24014	train-f1score:0.69437	eval-logloss:0.28004	eval-f1score:0.65223
# [200]	train-logloss:0.23655	train-f1score:0.69891	eval-logloss:0.27995	eval-f1score:0.65309
# [225]	train-logloss:0.23359	train-f1score:0.70245	eval-logloss:0.27991	eval-f1score:0.65441
# [250]	train-logloss:0.23033	train-f1score:0.70771	eval-logloss:0.28003	eval-f1score:0.65370
# [275]	train-logloss:0.22729	train-f1score:0.71209	eval-logloss:0.28043	eval-f1score:0.65530
# [300]	train-logloss:0.22397	train-f1score:0.71722	eval-logloss:0.28076	eval-f1score:0.65459
# [325]	train-logloss:0.22060	train-f1score:0.72457	eval-logloss:0.28134	eval-f1score:0.65548
# [350]	train-logloss:0.21836	train-f1score:0.72875	eval-logloss:0.28161	eval-f1score:0.65813
# [375]	train-logloss:0.21465	train-f1score:0.73415	eval-logloss:0.28173	eval-f1score:0.65973
# [400]	train-logloss:0.21187	train-f1score:0.73823	eval-logloss:0.28184	eval-f1score:0.66013
# [425]	train-logloss:0.20882	train-f1score:0.74483	eval-logloss:0.28241	eval-f1score:0.65925
# [450]	train-logloss:0.20597	train-f1score:0.74949	eval-logloss:0.28312	eval-f1score:0.66300
# [475]	train-logloss:0.20339	train-f1score:0.75299	eval-logloss:0.28338	eval-f1score:0.65861
# [499]	train-logloss:0.20052	train-f1score:0.75991	eval-logloss:0.28380	eval-f1score:0.65772
# xgboost our out of folds CV f1score is 0.6399419048608457
# --------------------------------------------------
# catboost training fold 1
# 0:	learn: 0.6444462	test: 0.6442056	best: 0.6442056 (0)	total: 122ms	remaining: 1m
# 25:	learn: 0.3091908	test: 0.3064933	best: 0.3064933 (25)	total: 1.41s	remaining: 25.8s
# 50:	learn: 0.2858596	test: 0.2845917	best: 0.2845917 (50)	total: 2.88s	remaining: 25.4s
# 75:	learn: 0.2803392	test: 0.2807319	best: 0.2807319 (75)	total: 4.29s	remaining: 23.9s
# 100:	learn: 0.2768606	test: 0.2790202	best: 0.2790202 (100)	total: 5.79s	remaining: 22.9s
# 125:	learn: 0.2745079	test: 0.2784612	best: 0.2784612 (125)	total: 7.3s	remaining: 21.7s
# 150:	learn: 0.2727573	test: 0.2782170	best: 0.2782021 (149)	total: 11.9s	remaining: 27.5s
# 175:	learn: 0.2711281	test: 0.2780756	best: 0.2780396 (170)	total: 14.7s	remaining: 27s
# 200:	learn: 0.2692983	test: 0.2779296	best: 0.2778398 (197)	total: 16.1s	remaining: 24s
# 225:	learn: 0.2675339	test: 0.2778602	best: 0.2778360 (215)	total: 17.6s	remaining: 21.4s
# 250:	learn: 0.2658969	test: 0.2777834	best: 0.2777720 (248)	total: 19.1s	remaining: 19s
# 275:	learn: 0.2645779	test: 0.2777855	best: 0.2776960 (263)	total: 20.7s	remaining: 16.8s
# 300:	learn: 0.2634181	test: 0.2777969	best: 0.2776960 (263)	total: 23.2s	remaining: 15.4s
# 325:	learn: 0.2620849	test: 0.2778199	best: 0.2776960 (263)	total: 25.3s	remaining: 13.5s
# 350:	learn: 0.2609444	test: 0.2778702	best: 0.2776960 (263)	total: 28s	remaining: 11.9s
# 375:	learn: 0.2595102	test: 0.2779040	best: 0.2776960 (263)	total: 32.3s	remaining: 10.7s
# 400:	learn: 0.2582157	test: 0.2777051	best: 0.2776755 (393)	total: 38s	remaining: 9.39s
# 425:	learn: 0.2570275	test: 0.2778758	best: 0.2776755 (393)	total: 41.3s	remaining: 7.18s
# 450:	learn: 0.2558330	test: 0.2777463	best: 0.2776755 (393)	total: 42.8s	remaining: 4.65s
# 475:	learn: 0.2546254	test: 0.2778247	best: 0.2776755 (393)	total: 44.4s	remaining: 2.24s
# 499:	learn: 0.2535614	test: 0.2778756	best: 0.2776755 (393)	total: 45.9s	remaining: 0us
#
# bestTest = 0.2776755296
# bestIteration = 393
#
# Shrink model to first 394 iterations.
# --------------------------------------------------
# catboost training fold 2
# 0:	learn: 0.6440207	test: 0.6443205	best: 0.6443205 (0)	total: 71.5ms	remaining: 35.7s
# 25:	learn: 0.3077514	test: 0.3122500	best: 0.3122500 (25)	total: 1.33s	remaining: 24.2s
# 50:	learn: 0.2842671	test: 0.2920083	best: 0.2920083 (50)	total: 3.46s	remaining: 30.5s
# 75:	learn: 0.2785950	test: 0.2884574	best: 0.2884574 (75)	total: 6.32s	remaining: 35.2s
# 100:	learn: 0.2757528	test: 0.2873252	best: 0.2873252 (100)	total: 8.85s	remaining: 35s
# 125:	learn: 0.2737050	test: 0.2864419	best: 0.2864419 (125)	total: 10.2s	remaining: 30.4s
# 150:	learn: 0.2718225	test: 0.2858213	best: 0.2857951 (147)	total: 11.6s	remaining: 26.8s
# 175:	learn: 0.2704702	test: 0.2853882	best: 0.2853882 (175)	total: 13s	remaining: 24s
# 200:	learn: 0.2687306	test: 0.2849070	best: 0.2849015 (199)	total: 14.5s	remaining: 21.6s
# 225:	learn: 0.2671573	test: 0.2844306	best: 0.2844004 (224)	total: 15.9s	remaining: 19.2s
# 250:	learn: 0.2658065	test: 0.2841772	best: 0.2841772 (250)	total: 17.3s	remaining: 17.2s
# 275:	learn: 0.2645202	test: 0.2839195	best: 0.2839133 (274)	total: 18.8s	remaining: 15.3s
# 300:	learn: 0.2632110	test: 0.2837798	best: 0.2837687 (291)	total: 21.6s	remaining: 14.3s
# 325:	learn: 0.2620628	test: 0.2837008	best: 0.2836926 (324)	total: 23.4s	remaining: 12.5s
# 350:	learn: 0.2609237	test: 0.2835920	best: 0.2835784 (349)	total: 24.8s	remaining: 10.5s
# 375:	learn: 0.2594320	test: 0.2836149	best: 0.2835656 (354)	total: 26.4s	remaining: 8.7s
# 400:	learn: 0.2582686	test: 0.2835705	best: 0.2835656 (354)	total: 27.9s	remaining: 6.89s
# 425:	learn: 0.2569240	test: 0.2834704	best: 0.2834704 (425)	total: 29.4s	remaining: 5.11s
# 450:	learn: 0.2556607	test: 0.2835464	best: 0.2834704 (425)	total: 30.9s	remaining: 3.36s
# 475:	learn: 0.2544650	test: 0.2834076	best: 0.2833863 (468)	total: 33.3s	remaining: 1.68s
# 499:	learn: 0.2534396	test: 0.2834234	best: 0.2833863 (468)	total: 36.2s	remaining: 0us
#
# bestTest = 0.2833862917
# bestIteration = 468
#
# Shrink model to first 469 iterations.
# --------------------------------------------------
# catboost training fold 3
# 0:	learn: 0.6443799	test: 0.6446280	best: 0.6446280 (0)	total: 64.2ms	remaining: 32.1s
# 25:	learn: 0.3079551	test: 0.3108610	best: 0.3108610 (25)	total: 1.35s	remaining: 24.6s
# 50:	learn: 0.2855217	test: 0.2899943	best: 0.2899943 (50)	total: 2.73s	remaining: 24.1s
# 75:	learn: 0.2797771	test: 0.2853591	best: 0.2853591 (75)	total: 4.16s	remaining: 23.2s
# 100:	learn: 0.2765721	test: 0.2835023	best: 0.2835023 (100)	total: 5.64s	remaining: 22.3s
# 125:	learn: 0.2742805	test: 0.2825769	best: 0.2825769 (125)	total: 7.1s	remaining: 21.1s
# 150:	learn: 0.2724475	test: 0.2819823	best: 0.2819823 (150)	total: 8.56s	remaining: 19.8s
# 175:	learn: 0.2711338	test: 0.2815621	best: 0.2815564 (174)	total: 10.6s	remaining: 19.5s
# 200:	learn: 0.2691548	test: 0.2807285	best: 0.2807285 (200)	total: 13s	remaining: 19.3s
# 225:	learn: 0.2676275	test: 0.2803886	best: 0.2803886 (225)	total: 14.4s	remaining: 17.5s
# 250:	learn: 0.2661338	test: 0.2798597	best: 0.2798597 (250)	total: 15.8s	remaining: 15.7s
# 275:	learn: 0.2645068	test: 0.2794633	best: 0.2794633 (275)	total: 17.3s	remaining: 14.1s
# 300:	learn: 0.2630429	test: 0.2791432	best: 0.2791432 (300)	total: 18.9s	remaining: 12.5s
# 325:	learn: 0.2617086	test: 0.2789570	best: 0.2789490 (317)	total: 20.5s	remaining: 10.9s
# 350:	learn: 0.2605958	test: 0.2787678	best: 0.2787654 (349)	total: 21.9s	remaining: 9.29s
# 375:	learn: 0.2593681	test: 0.2786211	best: 0.2786211 (375)	total: 24.3s	remaining: 8s
# 400:	learn: 0.2582017	test: 0.2785872	best: 0.2785872 (400)	total: 26.6s	remaining: 6.56s
# 425:	learn: 0.2570444	test: 0.2785338	best: 0.2785338 (425)	total: 28.1s	remaining: 4.87s
# 450:	learn: 0.2558361	test: 0.2785375	best: 0.2784632 (432)	total: 29.5s	remaining: 3.21s
# 475:	learn: 0.2546877	test: 0.2785257	best: 0.2784411 (458)	total: 31s	remaining: 1.56s
# 499:	learn: 0.2534210	test: 0.2785244	best: 0.2784411 (458)	total: 32.5s	remaining: 0us
#
# bestTest = 0.2784410835
# bestIteration = 458
#
# Shrink model to first 459 iterations.
# --------------------------------------------------
# catboost training fold 4
# 0:	learn: 0.6447357	test: 0.6440733	best: 0.6440733 (0)	total: 63.7ms	remaining: 31.8s
# 25:	learn: 0.3084085	test: 0.3008995	best: 0.3008995 (25)	total: 1.36s	remaining: 24.8s
# 50:	learn: 0.2869683	test: 0.2800081	best: 0.2800081 (50)	total: 2.71s	remaining: 23.9s
# 75:	learn: 0.2810509	test: 0.2756635	best: 0.2756635 (75)	total: 5.28s	remaining: 29.4s
# 100:	learn: 0.2779057	test: 0.2738704	best: 0.2738704 (100)	total: 7.29s	remaining: 28.8s
# 125:	learn: 0.2756226	test: 0.2734115	best: 0.2734115 (125)	total: 8.73s	remaining: 25.9s
# 150:	learn: 0.2736745	test: 0.2728284	best: 0.2728284 (150)	total: 10.1s	remaining: 23.5s
# 175:	learn: 0.2720038	test: 0.2723536	best: 0.2723536 (175)	total: 11.6s	remaining: 21.4s
# 200:	learn: 0.2704549	test: 0.2719316	best: 0.2719316 (200)	total: 13.1s	remaining: 19.4s
# 225:	learn: 0.2688402	test: 0.2715654	best: 0.2715654 (225)	total: 14.5s	remaining: 17.6s
# 250:	learn: 0.2675047	test: 0.2713655	best: 0.2713655 (250)	total: 15.9s	remaining: 15.8s
# 275:	learn: 0.2661961	test: 0.2711694	best: 0.2711546 (263)	total: 18.4s	remaining: 14.9s
# 300:	learn: 0.2646437	test: 0.2709335	best: 0.2709335 (300)	total: 20.6s	remaining: 13.6s
# 325:	learn: 0.2632465	test: 0.2708749	best: 0.2708413 (304)	total: 22.1s	remaining: 11.8s
# 350:	learn: 0.2619800	test: 0.2707019	best: 0.2707019 (350)	total: 23.6s	remaining: 10s
# 375:	learn: 0.2606074	test: 0.2707005	best: 0.2706954 (372)	total: 25.1s	remaining: 8.29s
# 400:	learn: 0.2594085	test: 0.2707305	best: 0.2706954 (372)	total: 26.7s	remaining: 6.59s
# 425:	learn: 0.2582905	test: 0.2708174	best: 0.2706954 (372)	total: 28.2s	remaining: 4.9s
# 450:	learn: 0.2569028	test: 0.2708953	best: 0.2706954 (372)	total: 29.8s	remaining: 3.23s
# 475:	learn: 0.2558955	test: 0.2708934	best: 0.2706954 (372)	total: 32.5s	remaining: 1.64s
# 499:	learn: 0.2547479	test: 0.2707511	best: 0.2706954 (372)	total: 34.3s	remaining: 0us
#
# bestTest = 0.2706954005
# bestIteration = 372
#
# Shrink model to first 373 iterations.
# --------------------------------------------------
# catboost training fold 5
# 0:	learn: 0.6439124	test: 0.6436372	best: 0.6436372 (0)	total: 71.4ms	remaining: 35.6s
# 25:	learn: 0.3085945	test: 0.3059660	best: 0.3059660 (25)	total: 1.35s	remaining: 24.7s
# 50:	learn: 0.2864664	test: 0.2841860	best: 0.2841860 (50)	total: 2.69s	remaining: 23.7s
# 75:	learn: 0.2806108	test: 0.2794024	best: 0.2794024 (75)	total: 4.15s	remaining: 23.2s
# 100:	learn: 0.2775900	test: 0.2773823	best: 0.2773823 (100)	total: 5.64s	remaining: 22.3s
# 125:	learn: 0.2753268	test: 0.2760924	best: 0.2760924 (125)	total: 7.08s	remaining: 21s
# 150:	learn: 0.2734320	test: 0.2752799	best: 0.2752799 (150)	total: 8.53s	remaining: 19.7s
# 175:	learn: 0.2718457	test: 0.2745345	best: 0.2745345 (175)	total: 11.3s	remaining: 20.8s
# 200:	learn: 0.2705772	test: 0.2742336	best: 0.2742326 (199)	total: 13s	remaining: 19.4s
# 225:	learn: 0.2688240	test: 0.2735306	best: 0.2735306 (225)	total: 14.4s	remaining: 17.5s
# 250:	learn: 0.2671262	test: 0.2730166	best: 0.2730166 (250)	total: 16.3s	remaining: 16.1s
# 275:	learn: 0.2658043	test: 0.2724501	best: 0.2724501 (275)	total: 19.1s	remaining: 15.5s
# 300:	learn: 0.2643553	test: 0.2721942	best: 0.2721805 (298)	total: 20.5s	remaining: 13.6s
# 325:	learn: 0.2630604	test: 0.2718120	best: 0.2718120 (325)	total: 22s	remaining: 11.8s
# 350:	learn: 0.2618504	test: 0.2716970	best: 0.2716970 (350)	total: 24.9s	remaining: 10.6s
# 375:	learn: 0.2605929	test: 0.2717315	best: 0.2716620 (359)	total: 26.7s	remaining: 8.79s
# 400:	learn: 0.2592279	test: 0.2717955	best: 0.2716620 (359)	total: 28.2s	remaining: 6.96s
# 425:	learn: 0.2580924	test: 0.2717542	best: 0.2716620 (359)	total: 29.7s	remaining: 5.15s
# 450:	learn: 0.2568575	test: 0.2718437	best: 0.2716620 (359)	total: 31.2s	remaining: 3.39s
# 475:	learn: 0.2557362	test: 0.2719691	best: 0.2716620 (359)	total: 32.7s	remaining: 1.65s
# 499:	learn: 0.2545964	test: 0.2719439	best: 0.2716620 (359)	total: 34.1s	remaining: 0us
#
# bestTest = 0.2716619597
# bestIteration = 359
#
# Shrink model to first 360 iterations.
# --------------------------------------------------
# catboost training fold 6
# 0:	learn: 0.6443711	test: 0.6451817	best: 0.6451817 (0)	total: 66ms	remaining: 32.9s
# 25:	learn: 0.3078604	test: 0.3158656	best: 0.3158656 (25)	total: 1.72s	remaining: 31.3s
# 50:	learn: 0.2852338	test: 0.2953190	best: 0.2953190 (50)	total: 4.18s	remaining: 36.8s
# 75:	learn: 0.2789795	test: 0.2907755	best: 0.2907755 (75)	total: 5.66s	remaining: 31.6s
# 100:	learn: 0.2757421	test: 0.2888518	best: 0.2888518 (100)	total: 7.1s	remaining: 28.1s
# 125:	learn: 0.2735766	test: 0.2878165	best: 0.2878165 (125)	total: 8.53s	remaining: 25.3s
# 150:	learn: 0.2718045	test: 0.2872642	best: 0.2872642 (150)	total: 9.9s	remaining: 22.9s
# 175:	learn: 0.2701306	test: 0.2868286	best: 0.2868286 (175)	total: 11.3s	remaining: 20.8s
# 200:	learn: 0.2683107	test: 0.2864424	best: 0.2864248 (197)	total: 12.8s	remaining: 19s
# 225:	learn: 0.2668803	test: 0.2861770	best: 0.2861770 (225)	total: 14.2s	remaining: 17.2s
# 250:	learn: 0.2655390	test: 0.2859933	best: 0.2859933 (250)	total: 16.8s	remaining: 16.6s
# 275:	learn: 0.2637655	test: 0.2857344	best: 0.2857299 (272)	total: 18.7s	remaining: 15.2s
# 300:	learn: 0.2623048	test: 0.2855661	best: 0.2855374 (299)	total: 20.2s	remaining: 13.4s
# 325:	learn: 0.2608171	test: 0.2854057	best: 0.2854057 (325)	total: 21.7s	remaining: 11.6s
# 350:	learn: 0.2594495	test: 0.2852559	best: 0.2851879 (345)	total: 23.3s	remaining: 9.88s
# 375:	learn: 0.2582008	test: 0.2852413	best: 0.2851879 (345)	total: 24.8s	remaining: 8.17s
# 400:	learn: 0.2570458	test: 0.2849810	best: 0.2849810 (400)	total: 26.3s	remaining: 6.49s
# 425:	learn: 0.2558355	test: 0.2850288	best: 0.2849263 (421)	total: 28s	remaining: 4.86s
# 450:	learn: 0.2545207	test: 0.2850689	best: 0.2849263 (421)	total: 30.8s	remaining: 3.35s
# 475:	learn: 0.2534127	test: 0.2849941	best: 0.2849263 (421)	total: 32.5s	remaining: 1.64s
# 499:	learn: 0.2523771	test: 0.2851956	best: 0.2849263 (421)	total: 34s	remaining: 0us
#
# bestTest = 0.2849262771
# bestIteration = 421
#
# Shrink model to first 422 iterations.
# --------------------------------------------------
# catboost training fold 7
# 0:	learn: 0.6437848	test: 0.6436270	best: 0.6436270 (0)	total: 59.1ms	remaining: 29.5s
# 25:	learn: 0.3081140	test: 0.3095257	best: 0.3095257 (25)	total: 1.34s	remaining: 24.4s
# 50:	learn: 0.2848672	test: 0.2884108	best: 0.2884108 (50)	total: 2.72s	remaining: 23.9s
# 75:	learn: 0.2789834	test: 0.2846336	best: 0.2846336 (75)	total: 4.14s	remaining: 23.1s
# 100:	learn: 0.2758628	test: 0.2832390	best: 0.2832390 (100)	total: 5.58s	remaining: 22s
# 125:	learn: 0.2736563	test: 0.2825824	best: 0.2825396 (121)	total: 7.35s	remaining: 21.8s
# 150:	learn: 0.2719866	test: 0.2821251	best: 0.2821044 (146)	total: 10.1s	remaining: 23.3s
# 175:	learn: 0.2703798	test: 0.2816654	best: 0.2816654 (175)	total: 11.6s	remaining: 21.3s
# 200:	learn: 0.2689149	test: 0.2813607	best: 0.2813607 (200)	total: 13.1s	remaining: 19.4s
# 225:	learn: 0.2672047	test: 0.2810625	best: 0.2810527 (223)	total: 14.5s	remaining: 17.6s
# 250:	learn: 0.2655081	test: 0.2806952	best: 0.2806866 (249)	total: 16.1s	remaining: 15.9s
# 275:	learn: 0.2640970	test: 0.2804701	best: 0.2804701 (275)	total: 17.5s	remaining: 14.2s
# 300:	learn: 0.2628483	test: 0.2803026	best: 0.2802702 (292)	total: 19s	remaining: 12.6s
# 325:	learn: 0.2617018	test: 0.2802522	best: 0.2802217 (323)	total: 20.7s	remaining: 11.1s
# 350:	learn: 0.2604876	test: 0.2799843	best: 0.2799423 (347)	total: 23.6s	remaining: 10s
# 375:	learn: 0.2592869	test: 0.2799149	best: 0.2799149 (375)	total: 25.2s	remaining: 8.3s
# 400:	learn: 0.2579827	test: 0.2797791	best: 0.2797791 (400)	total: 26.8s	remaining: 6.61s
# 425:	learn: 0.2567112	test: 0.2796491	best: 0.2795926 (419)	total: 28.3s	remaining: 4.91s
# 450:	learn: 0.2555149	test: 0.2796720	best: 0.2795765 (433)	total: 29.8s	remaining: 3.24s
# 475:	learn: 0.2544608	test: 0.2798057	best: 0.2795765 (433)	total: 31.3s	remaining: 1.58s
# 499:	learn: 0.2534797	test: 0.2796496	best: 0.2795765 (433)	total: 32.7s	remaining: 0us
#
# bestTest = 0.2795765016
# bestIteration = 433
#
# Shrink model to first 434 iterations.
# catboost our out of folds CV f1score is 0.643645715001716

# %%
def lightgbm_inference(x_test: pd.DataFrame):
    test_pred = np.zeros(len(x_test))
    for fold in range(CFG.n_folds):
        model = pickle.load(open(CFG.MODEL_DATA_PATH / f'lightgbm_fold{fold + 1}_seed{CFG.seed}_ver{CFG.VER}.pkl', 'rb'))
        # Predict
        pred = model.predict(x_test)
        test_pred += pred
    return test_pred / CFG.n_folds
def xgboost_inference(x_test: pd.DataFrame):
    test_pred = np.zeros(len(x_test))
    for fold in range(CFG.n_folds):
        model = pickle.load(open(CFG.MODEL_DATA_PATH / f'xgboost_fold{fold + 1}_seed{CFG.seed}_ver{CFG.VER}.pkl', 'rb'))
        # Predict
        pred = model.predict(xgb.DMatrix(x_test))
        test_pred += pred
    return test_pred / CFG.n_folds

def catboost_inference(x_test: pd.DataFrame):
    test_pred = np.zeros(len(x_test))
    for fold in range(CFG.n_folds):
        model = pickle.load(open(CFG.MODEL_DATA_PATH / f'catboost_fold{fold + 1}_seed{CFG.seed}_ver{CFG.VER}.pkl', 'rb'))
        # Predict
        pred = model.predict_proba(x_test)[:, 1]
        test_pred += pred
    return test_pred / CFG.n_folds

def gradient_boosting_model_inference(method: str, test_df: pd.DataFrame, features: list, categorical_features: list):
    x_test = test_df[features]
    if method == 'lightgbm':
        test_pred = lightgbm_inference(x_test)
    if method == 'xgboost':
        test_pred = xgboost_inference(x_test)
    if method == 'catboost':
        test_pred = catboost_inference(x_test)
    return test_pred

def Predicting(input_df: pd.DataFrame, features: list, categorical_features: list):
    output_df = input_df.copy()
    output_df['pred_prob'] = 0
    for method in CFG.METHOD_LIST:
        output_df[f'{method}_pred_prob'] = gradient_boosting_model_inference(method, input_df, features, categorical_features)
        output_df['pred_prob'] += CFG.model_weight_dict[method] * output_df[f'{method}_pred_prob']
    return output_df

# %%
test_df = Predicting(test_df, features, categorical_features)

# %%
def Postprocessing(train_df: pd.DataFrame(), test_df: pd.DataFrame()) -> (pd.DataFrame(), pd.DataFrame()):
    train_df['pred_prob'] = 0
    for method in CFG.METHOD_LIST:
        oof_df = pd.read_csv(CFG.OOF_DATA_PATH / f'oof_{method}_seed{CFG.seed}_ver{CFG.VER}.csv')
        train_df['pred_prob'] += CFG.model_weight_dict[method] * oof_df[f'{method}_prediction']
    best_score = 0
    best_v = 0
    for v in tqdm(np.arange(1000) / 1000):
        score = f1_score(oof_df[CFG.target_col], train_df[f'pred_prob'] >= v, average='macro')
        if score > best_score:
            best_score = score
            best_v = v
    print(best_score, best_v)
    test_df['target'] = np.where(test_df['pred_prob'] >= best_v, 1, 0)
    return train_df, test_df

# %%
train_df, test_df = Postprocessing(train_df, test_df)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 0.6814510713544528 0.736

# %%
test_df[['target']].to_csv(CFG.SUB_DATA_PATH / f'seed{CFG.seed}_ver{CFG.VER}_{CFG.AUTHOR}_submission.csv', header=False)

# %% [markdown]
# 特徴量の重要度を確認する方法

# %%
model = pickle.load(open(CFG.MODEL_DATA_PATH / f'lightgbm_fold1_seed42_ver1.pkl', 'rb'))
importance_df = pd.DataFrame(model.feature_importance(), index=features, columns=['importance'])
importance_df['importance'] = importance_df['importance'] / np.sum(importance_df['importance'])
importance_df.sort_values('importance', ascending=False)
# Out:
#                               importance
# State                           0.141152
# Term                            0.097531
# City_count_encoding             0.084156
# SBA_Appv                        0.082716
# NoEmp                           0.081481
# DisbursementGross               0.064198
# ApprovalFY                      0.059671
# Sector                          0.058025
# RetainedJob                     0.047942
# CreateJob                       0.045267
# GrAppv                          0.042798
# BankState_count_encoding        0.034362
# Sector_count_encoding           0.029012
# RevLineCr_count_encoding        0.028601
# FranchiseCode_count_encoding    0.022222
# State_count_encoding            0.020576
# LowDoc_count_encoding           0.018519
# UrbanRural_count_encoding       0.016461
# LowDoc                          0.013992
# RevLineCr                       0.005761
# UrbanRural                      0.005556
